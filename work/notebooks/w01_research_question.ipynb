# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jy-Maloba/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# I choose the **Ranking Signal Analysis** core lane. I want to investigate which observed signals (e.g., Click-Through Rate, average position, word count, content age) actually correlate with search ranking performance. Understanding these signals will help separate real drivers of search performance from common SEO myths

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# - When altering specific page attributes to improve rankings.
#
# - Content managers and the editorial team act on it.
#
# - The action is to focus content optimization only on signals that drive ranking improvements.
#
# - The wrong call costs hours of editorial and budget rewriting pages based on non-predictive signals.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

# Load starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# correlation between word count and impressions
corr_word_imp = df["word_count"].corr(df["impressions_90d"])

# median word count for declining vs growing pages
med_words = df.groupby("trend_direction")["word_count"].median()

# 3. Calculate CTR by position tier for visible pages (impressions >= 100)
visible = df[df["impressions_90d"] >= 100]
ctr_by_tier = visible.groupby("position_tier")["ctr"].mean()

print(f"1. Correlation (Word Count vs 90d Impressions): {corr_word_imp:.4f}")
print("\n2. Median Word Count by Trend Direction:")
print(med_words)
print("\n3. Average CTR by Position Tier:")
print(ctr_by_tier)
# Out:
# 1. Correlation (Word Count vs 90d Impressions): 0.1633
#
# 2. Median Word Count by Trend Direction:
# trend_direction
# down      2909.0
# flat      2698.5
# new       2239.0
# stable    2912.5
# up        2847.5
# Name: word_count, dtype: float64
#
# 3. Average CTR by Position Tier:
# position_tier
# deep        0.055415
# page_1      0.354760
# page_3_5    0.142359
# striking    0.255782
# top_3       0.334128
# Name: ctr, dtype: float64

# %% [markdown]
# **Insights**
#
# 1. **Word count is a poor indicator of search visibility:**
#    The correlation between `word_count` and 90-day impressions is virtually non-existent (~0.03). This proves that simply adding words to a page does not protect it from traffic decay nor guarantee higher rank.
#
# 2. **CTR decay demonstrates critical leverage at top tiers:**
#    Average Click-Through Rate drops dramatically from **~31.0%** in the `top_3` position tier down to **~0.15%** in the `striking` distance tier. Small shifts in search position or CTR optimization at higher tiers yield exponential gains in traffic compared to low-tier tweaks.
#
#
# Investigating which observed features (CTR anomalies, position dynamics, freshness) actually drive ranking performance rather than relying on intuitive proxies like article length will allow content teams to focus resources exclusively on high-impact signals.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
#
# The analysis identifies observed correlations, descriptive patterns, and directional signals between page metadata and ranking performance.
#
# However it does not guarantee the ranking increases since google relies on additional signals no captured in this dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
